# %%
# set up environment by importing all necessary libraries.

# Matplotlib forms basis for visualization in Python
import matplotlib.pyplot as plt

import seaborn as sns

import pandas as pd

# %%
# load dataset and drop N/A

data_url = "https://raw.githubusercontent.com/wrongjun/Video_Game_Finding/master/Video_Games_Sales_as_at_22_Dec_2016.csv"

original_df = pd.read_csv(data_url,error_bad_lines=False)
df = original_df
print(df.shape)
# Out:
# (16719, 16)

# %%
df = original_df.dropna()
print(df.shape)
# Out:
# (6825, 16)

# %%
# convert some attributes to it's proper type
df['User_Score'] = df['User_Score'].astype('float64')
df['Year_of_Release'] = df['Year_of_Release'].astype('int64')
df['User_Count'] = df['User_Count'].astype('int64')
df['Critic_Count'] = df['Critic_Count'].astype('int64')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
original_df.info()
df1 = original_df[['Platform','Genre','Rating','Global_Sales','NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df1.dropna()
df1.info()
df2 =pd.get_dummies(df1, columns=['Genre','Platform','Rating'])
df1.sample(10)
df2.sample(10)
y = df2.as_matrix(columns=['Global_Sales'])
df2.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 8 columns):
# Platform        16719 non-null object
# Genre           16717 non-null object
# Rating          9950 non-null object
# Global_Sales    16719 non-null float64
# NA_Sales        16719 non-null float64
# EU_Sales        16719 non-null float64
# JP_Sales        16719 non-null float64
# Other_Sales     16719 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 1.0+ MB
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Index(['Global_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales',
#        'Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
#        'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
#        'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
# ...

# %%
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

se_df = sm.add_constant(df2)

est = sm.OLS(se_df['NA_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting',
       'Genre_Misc', 'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing',
       'Genre_Role-Playing', 'Genre_Shooter', 'Genre_Simulation',
       'Genre_Sports', 'Genre_Strategy', 'Platform_2600', 'Platform_3DO',
       'Platform_3DS', 'Platform_DC', 'Platform_DS', 'Platform_GB',
       'Platform_GBA', 'Platform_GC', 'Platform_GEN', 'Platform_GG',
       'Platform_N64', 'Platform_NES', 'Platform_NG', 'Platform_PC',
       'Platform_PCFX', 'Platform_PS', 'Platform_PS2', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_SAT',
       'Platform_SCD', 'Platform_SNES', 'Platform_TG16', 'Platform_WS',
       'Platform_Wii', 'Platform_WiiU', 'Platform_X360', 'Platform_XB',
       'Platform_XOne', 'Rating_AO', 'Rating_E', 'Rating_E10+', 'Rating_EC',
       'Rating_K-A', 'Rating_M', 'Rating_RP', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               NA_Sales   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     21.24
# Date:                Mon, 13 May 2019   Prob (F-statistic):          2.68e-183
# Time:                        22:49:18   Log-Likelihood:                -19756.
# No. Observations:               16719   AIC:                         3.961e+04
# Df Residuals:                   16668   BIC:                         4.001e+04
# Df Model:                          50
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Genre_Action          -0.2369      0.579     -0.409      0.683      -1.372       0.898
# ...

# %%
df = pd.get_dummies(original_df, columns=['Genre'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 27 columns):
# Name                  16717 non-null object
# Platform              16719 non-null object
# Year_of_Release       16450 non-null float64
# Publisher             16665 non-null object
# NA_Sales              16719 non-null float64
# EU_Sales              16719 non-null float64
# JP_Sales              16719 non-null float64
# Other_Sales           16719 non-null float64
# Global_Sales          16719 non-null float64
# Critic_Score          8137 non-null float64
# Critic_Count          8137 non-null float64
# User_Score            10015 non-null object
# User_Count            7590 non-null float64
# Developer             10096 non-null object
# Rating                9950 non-null object
# Genre_Action          16719 non-null uint8
# Genre_Adventure       16719 non-null uint8
# Genre_Fighting        16719 non-null uint8
# Genre_Misc            16719 non-null uint8
# ...

# %%
df.info()
df = df.dropna()
df.info()
A = df.as_matrix(columns=['Critic_Score',
       'Critic_Count', 'User_Score',
       'Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 27 columns):
# Name                  16717 non-null object
# Platform              16719 non-null object
# Year_of_Release       16450 non-null float64
# Publisher             16665 non-null object
# NA_Sales              16719 non-null float64
# EU_Sales              16719 non-null float64
# JP_Sales              16719 non-null float64
# Other_Sales           16719 non-null float64
# Global_Sales          16719 non-null float64
# Critic_Score          8137 non-null float64
# Critic_Count          8137 non-null float64
# User_Score            10015 non-null object
# User_Count            7590 non-null float64
# Developer             10096 non-null object
# Rating                9950 non-null object
# Genre_Action          16719 non-null uint8
# Genre_Adventure       16719 non-null uint8
# Genre_Fighting        16719 non-null uint8
# Genre_Misc            16719 non-null uint8
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating',
#        'Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
#        'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
#        'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 27 columns):
# Name                  6825 non-null object
# Platform              6825 non-null object
# Year_of_Release       6825 non-null float64
# Publisher             6825 non-null object
# NA_Sales              6825 non-null float64
# EU_Sales              6825 non-null float64
# JP_Sales              6825 non-null float64
# Other_Sales           6825 non-null float64
# Global_Sales          6825 non-null float64
# Critic_Score          6825 non-null float64
# Critic_Count          6825 non-null float64
# User_Score            6825 non-null object
# User_Count            6825 non-null float64
# Developer             6825 non-null object
# Rating                6825 non-null object
# Genre_Action          6825 non-null uint8
# Genre_Adventure       6825 non-null uint8
# Genre_Fighting        6825 non-null uint8
# Genre_Misc            6825 non-null uint8
# ...

# %%
df1.info()
df1.dropna()
df1.Rating.value_counts()
df1 = df1.loc[df1['Rating'] != 'AO']
df1.Rating.value_counts()
df1 = df1.loc[df1['Rating'] != 'EC']
df1.Rating.value_counts()
df1 = df1.loc[df1['Rating'] != 'RP']
df1.Rating.value_counts()
df1 = df1.loc[df1['Rating'] != 'K-A']
df1.Rating.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 8 columns):
# Platform        16719 non-null object
# Genre           16717 non-null object
# Rating          9950 non-null object
# Global_Sales    16719 non-null float64
# NA_Sales        16719 non-null float64
# EU_Sales        16719 non-null float64
# JP_Sales        16719 non-null float64
# Other_Sales     16719 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 1.0+ MB
# E       3991
# T       2961
# M       1563
# E10+    1420
# Name: Rating, dtype: int64

# %%
df1.Platform.value_counts()
# Out:
# PS2     2160
# DS      2150
# PS3     1331
# Wii     1318
# X360    1262
# PSP     1209
# PS      1196
# PC       967
# XB       823
# GBA      822
# GC       555
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
df1['Rating'] = df1.Rating.fillna('N')

df1.info()
for i in list(df1.Rating.unique()):
  k = df1.loc[df1['Rating']==i].Global_Sales.mean()
  print('mean of %s : %f'%(i,k))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16704 entries, 0 to 16718
# Data columns (total 8 columns):
# Platform        16704 non-null object
# Genre           16702 non-null object
# Rating          16704 non-null object
# Global_Sales    16704 non-null float64
# NA_Sales        16704 non-null float64
# EU_Sales        16704 non-null float64
# JP_Sales        16704 non-null float64
# Other_Sales     16704 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 1.1+ MB
# mean of E : 0.610599
# mean of N : 0.421216
# mean of M : 0.942956
# mean of T : 0.504694
# mean of E10+ : 0.461838

# %%
df2 =pd.get_dummies(df1, columns=['Genre','Platform','Rating'])

se_df = sm.add_constant(df2)

est = sm.OLS(se_df['Global_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting',
       'Genre_Misc', 'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing',
       'Genre_Role-Playing', 'Genre_Shooter', 'Genre_Simulation',
       'Genre_Sports', 'Genre_Strategy', 'Platform_2600', 'Platform_3DO',
       'Platform_3DS', 'Platform_DC', 'Platform_DS', 'Platform_GB',
       'Platform_GBA', 'Platform_GC', 'Platform_GEN', 'Platform_GG',
       'Platform_N64', 'Platform_NES', 'Platform_NG', 'Platform_PC',
       'Platform_PCFX', 'Platform_PS', 'Platform_PS2', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_SAT',
       'Platform_SCD', 'Platform_SNES', 'Platform_TG16', 'Platform_WS',
       'Platform_Wii', 'Platform_WiiU', 'Platform_X360', 'Platform_XB',
       'Platform_XOne',  'Rating_E', 'Rating_E10+', 
        'Rating_M', 'Rating_T','Rating_N']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     21.36
# Date:                Mon, 13 May 2019   Prob (F-statistic):          2.11e-170
# Time:                        22:49:19   Log-Likelihood:                -30527.
# No. Observations:               16704   AIC:                         6.115e+04
# Df Residuals:                   16657   BIC:                         6.151e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Genre_Action          -0.2802      1.105     -0.254      0.800      -2.445       1.885
# ...

# %%
original_df.Rating.value_counts()
# Out:
# E       3991
# T       2961
# M       1563
# E10+    1420
# EC         8
# RP         3
# K-A        3
# AO         1
# Name: Rating, dtype: int64

# %%
original_df.Genre.value_counts()
# Out:
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       874
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
original_df.Platform.value_counts()
# Out:
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
drop_Platform = ['DC','GEN','NG','WS','SCD','TG16','PCFX','GG','3DO']
original_df.Platform.value_counts()

df1.Rating.value_counts()
for i in drop_Platform:
  df1 = df1.loc[df1['Platform'] !=i]
len(df1.Platform.unique())
# Out:
# 22

# %%
df2.columns
# Out:
# Index(['Global_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales',
#        'Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
#        'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
#        'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
#        'Platform_2600', 'Platform_3DO', 'Platform_3DS', 'Platform_DC',
#        'Platform_DS', 'Platform_GB', 'Platform_GBA', 'Platform_GC',
#        'Platform_GEN', 'Platform_GG', 'Platform_N64', 'Platform_NES',
#        'Platform_NG', 'Platform_PC', 'Platform_PCFX', 'Platform_PS',
#        'Platform_PS2', 'Platform_PS3', 'Platform_PS4', 'Platform_PSP',
#        'Platform_PSV', 'Platform_SAT', 'Platform_SCD', 'Platform_SNES',
#        'Platform_TG16', 'Platform_WS', 'Platform_Wii', 'Platform_WiiU',
#        'Platform_X360', 'Platform_XB', 'Platform_XOne', 'Rating_E',
#        'Rating_E10+', 'Rating_M', 'Rating_N', 'Rating_T'],
#       dtype='object')

# %%
df2 =pd.get_dummies(df1, columns=['Genre','Platform','Rating'])

se_df = sm.add_constant(df2)

est = sm.OLS(se_df['Global_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_2600', 'Platform_3DS', 'Platform_DS', 'Platform_GB',
       'Platform_GBA', 'Platform_GC', 'Platform_N64', 'Platform_NES',
       'Platform_PC', 'Platform_PS', 'Platform_PS2', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_SAT',
       'Platform_SNES', 'Platform_Wii', 'Platform_WiiU', 'Platform_X360',
       'Platform_XB', 'Platform_XOne', 'Rating_E', 'Rating_E10+', 'Rating_M',
       'Rating_N', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     26.94
# Date:                Mon, 13 May 2019   Prob (F-statistic):          1.20e-174
# Time:                        22:49:19   Log-Likelihood:                -30363.
# No. Observations:               16592   AIC:                         6.080e+04
# Df Residuals:                   16555   BIC:                         6.108e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Genre_Action           0.1651      0.027      6.028      0.000       0.111       0.219
# ...

# %%
# get rid of global sales outlier
df1.Global_Sales.quantile([0.025,0.975])

df1=df1.loc[df1['Global_Sales']<=3.25]

df2 =pd.get_dummies(df1, columns=['Genre','Platform','Rating'])

se_df = sm.add_constant(df2)

est = sm.OLS(se_df['Global_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_2600', 'Platform_3DS', 'Platform_DS', 'Platform_GB',
       'Platform_GBA', 'Platform_GC', 'Platform_N64', 'Platform_NES',
       'Platform_PC', 'Platform_PS', 'Platform_PS2', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_SAT',
       'Platform_SNES', 'Platform_Wii', 'Platform_WiiU', 'Platform_X360',
       'Platform_XB', 'Platform_XOne', 'Rating_E', 'Rating_E10+', 'Rating_M',
       'Rating_N', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.112
# Method:                 Least Squares   F-statistic:                     57.62
# Date:                Mon, 13 May 2019   Prob (F-statistic):               0.00
# Time:                        22:49:19   Log-Likelihood:                -11507.
# No. Observations:               16178   AIC:                         2.309e+04
# Df Residuals:                   16141   BIC:                         2.337e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Genre_Action           0.1220      0.009     13.439      0.000       0.104       0.140
# ...

# %%
original_df.info()
df3 = original_df.loc[original_df['Global_Sales']>=3.25]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 419 entries, 0 to 418
# Data columns (total 16 columns):
# ...

# %%
df3.sort_values(by=['Global_Sales'],ascending=False)
# Out:
#                                                   Name Platform  \
# 0                                           Wii Sports      Wii
# 1                                    Super Mario Bros.      NES
# 2                                       Mario Kart Wii      Wii
# 3                                    Wii Sports Resort      Wii
# 4                             Pokemon Red/Pokemon Blue       GB
# 5                                               Tetris       GB
# 6                                New Super Mario Bros.       DS
# 7                                             Wii Play      Wii
# 8                            New Super Mario Bros. Wii      Wii
# 9                                            Duck Hunt      NES
# 10                                          Nintendogs       DS
# 11                                       Mario Kart DS       DS
# 12                         Pokemon Gold/Pokemon Silver       GB
# 13                                             Wii Fit      Wii
# ...

# %% [markdown]
# Adding Year as a factor into the regrussion model.

# %%
original_df.Year_of_Release.value_counts()
# Out:
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2007.0    1197
# 2011.0    1136
# 2006.0    1006
# 2005.0     939
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2012.0     653
# 2015.0     606
# 2014.0     581
# 2013.0     544
# 2016.0     502
# 2001.0     482
# 1998.0     379
# 2000.0     350
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      62
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year_of_Release, dtype: int64

# %%
year_filter_df = original_df.loc[original_df['Year_of_Release']>2010]

# %%
year_filter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4026 entries, 16 to 16718
# Data columns (total 16 columns):
# Name               4026 non-null object
# Platform           4026 non-null object
# Year_of_Release    4026 non-null float64
# Genre              4026 non-null object
# Publisher          4021 non-null object
# NA_Sales           4026 non-null float64
# EU_Sales           4026 non-null float64
# JP_Sales           4026 non-null float64
# Other_Sales        4026 non-null float64
# Global_Sales       4026 non-null float64
# Critic_Score       1812 non-null float64
# Critic_Count       1812 non-null float64
# User_Score         2382 non-null object
# User_Count         2032 non-null float64
# Developer          2421 non-null object
# Rating             2315 non-null object
# dtypes: float64(9), object(7)
# memory usage: 534.7+ KB

# %% [markdown]
# take sale that higher than 97.5% out.

# %%
year_filter_df.Global_Sales.quantile([0.025,0.975])
# Out:
# 0.025    0.01000
# 0.975    3.33125
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Taking out all of the outlier

# %%
year_filter_df = year_filter_df.loc[year_filter_df['Global_Sales']<=3.33]

# %%
year_filter_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# Taking out Publisher critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating.

# %%
year_filter_df=year_filter_df.drop(['Name','Critic_Score',
       'Critic_Count', 'User_Score', 'User_Count', 'Developer','Publisher'],axis=1)

# %%
year_filter_df.head(1)
# Out:
#     Platform  Year_of_Release   Genre  NA_Sales  EU_Sales  JP_Sales  \
# 406      3DS           2015.0  Action      0.27      0.21      2.79
#
#      Other_Sales  Global_Sales Rating
# 406         0.05          3.32    NaN

# %%
#drop all the platform outlier
year_filter_df = year_filter_df.loc[year_filter_df['Year_of_Release']!=2020.0]
year_filter_df = year_filter_df.loc[year_filter_df['Year_of_Release']!=2017.0]
year_filter_df = year_filter_df.loc[year_filter_df['Platform']!='PS2']
year_filter_df = year_filter_df.loc[year_filter_df['Rating']!='EC']
year_filter_df = year_filter_df.loc[year_filter_df['Rating']!='RP']

# %%
year_filter_df.Rating.value_counts()
# Out:
# T       606
# E       597
# M       576
# E10+    449
# Name: Rating, dtype: int64

# %%
year_filter_df.Year_of_Release.value_counts()
# Out:
# 2011.0    1103
# 2012.0     638
# 2015.0     591
# 2014.0     559
# 2013.0     525
# 2016.0     496
# Name: Year_of_Release, dtype: int64

# %%
year_filter_df = pd.get_dummies(year_filter_df, columns=['Genre','Platform','Rating','Year_of_Release'])

# %%
year_filter_df.head(4)
# Out:
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Genre_Action  \
# 406      0.27      0.21      2.79         0.05          3.32             1
# 410      1.90      1.11      0.01         0.29          3.30             1
# 412      0.09      0.00      3.18         0.01          3.28             0
# 413      2.61      0.33      0.00         0.34          3.28             0
#
#      Genre_Adventure  Genre_Fighting  Genre_Misc  Genre_Platform  ...  \
# 406                0               0           0               0  ...
# 410                0               0           0               0  ...
# 412                0               0           0               0  ...
# 413                0               0           0               0  ...
#
#      Rating_E  Rating_E10+  Rating_M  Rating_T  Year_of_Release_2011.0  \
# 406         0            0         0         0                       0
# 410         0            0         1         0                       0
# ...

# %% [markdown]
# Take all the sales to other y

# %%
se_df = sm.add_constant(year_filter_df)

est = sm.OLS(se_df['Global_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
       'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
       'Rating_E10+','Rating_M', 'Rating_T',
       'Year_of_Release_2011.0', 'Year_of_Release_2012.0',
       'Year_of_Release_2013.0', 'Year_of_Release_2014.0',
       'Year_of_Release_2015.0', 'Year_of_Release_2016.0']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.180
# Model:                            OLS   Adj. R-squared:                  0.174
# Method:                 Least Squares   F-statistic:                     28.49
# Date:                Mon, 13 May 2019   Prob (F-statistic):          9.23e-144
# Time:                        22:49:20   Log-Likelihood:                -2616.3
# No. Observations:                3912   AIC:                             5295.
# Df Residuals:                    3881   BIC:                             5489.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Genre_Action              -0.1472      0.033     -4.479      0.000      -0.212      -0.083
# ...

# %%
se_df = sm.add_constant(year_filter_df)

est = sm.OLS(se_df['NA_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
       'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
       'Rating_E10+','Rating_M', 'Rating_T',
       'Year_of_Release_2011.0', 'Year_of_Release_2012.0',
       'Year_of_Release_2013.0', 'Year_of_Release_2014.0',
       'Year_of_Release_2015.0', 'Year_of_Release_2016.0']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               NA_Sales   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.215
# Method:                 Least Squares   F-statistic:                     36.70
# Date:                Mon, 13 May 2019   Prob (F-statistic):          3.01e-185
# Time:                        22:49:47   Log-Likelihood:                -47.502
# No. Observations:                3912   AIC:                             157.0
# Df Residuals:                    3881   BIC:                             351.4
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Genre_Action               0.0080      0.008      0.990      0.322      -0.008       0.024
# ...

# %%
se_df = sm.add_constant(year_filter_df)

est = sm.OLS(se_df['JP_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
       'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
       'Rating_E10+','Rating_M', 'Rating_T',
       'Year_of_Release_2011.0', 'Year_of_Release_2012.0',
       'Year_of_Release_2013.0', 'Year_of_Release_2014.0',
       'Year_of_Release_2015.0', 'Year_of_Release_2016.0']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               JP_Sales   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     18.58
# Date:                Mon, 13 May 2019   Prob (F-statistic):           2.62e-91
# Time:                        22:49:47   Log-Likelihood:                 2336.5
# No. Observations:                3912   AIC:                            -4611.
# Df Residuals:                    3881   BIC:                            -4417.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Genre_Action               0.0103      0.004      2.346      0.019       0.002       0.019
# ...

# %%
se_df = sm.add_constant(year_filter_df)

est = sm.OLS(se_df['EU_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
       'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
       'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
       'Rating_E10+','Rating_M', 'Rating_T',
       'Year_of_Release_2011.0', 'Year_of_Release_2012.0',
       'Year_of_Release_2013.0', 'Year_of_Release_2014.0',
       'Year_of_Release_2015.0', 'Year_of_Release_2016.0']]
            ).fit()

print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               EU_Sales   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     26.80
# Date:                Mon, 13 May 2019   Prob (F-statistic):          5.28e-135
# Time:                        22:49:47   Log-Likelihood:                 1001.5
# No. Observations:                3912   AIC:                            -1941.
# Df Residuals:                    3881   BIC:                            -1747.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Genre_Action               0.0059      0.006      0.957      0.339      -0.006       0.018
# ...

# %%
year =['Year_of_Release_2011.0', 'Year_of_Release_2012.0',
       'Year_of_Release_2013.0', 'Year_of_Release_2014.0',
       'Year_of_Release_2015.0', 'Year_of_Release_2016.0']

for tmp_str in year:
  print('--------------------------------------------------')
  print(tmp_str)
  new = year_filter_df.loc[year_filter_df[tmp_str]==1]

  se_df = sm.add_constant(new)

  est = sm.OLS(se_df['Global_Sales'], 
               se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
         'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
         'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
         'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
         'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
         'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
         'Rating_E10+','Rating_M', 'Rating_T']]
              ).fit()

  print(est.summary())
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# --------------------------------------------------
# Year_of_Release_2011.0
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.182
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     10.91
# Date:                Mon, 13 May 2019   Prob (F-statistic):           2.46e-34
# Time:                        22:49:47   Log-Likelihood:                -643.76
# No. Observations:                1103   AIC:                             1334.
# Df Residuals:                    1080   BIC:                             1449.
# Df Model:                          22
# ...

# %% [markdown]
# 2011

# %%
print('--------------------------------------------------')
print(2011)
new = year_filter_df.loc[year_filter_df['Year_of_Release_2011.0']==1]
se_df = sm.add_constant(new)

est = sm.OLS(se_df['Global_Sales'], 
             se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
       'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
       'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
       'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
        'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
       'Platform_X360', 'Rating_E',
       'Rating_E10+','Rating_M', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
# --------------------------------------------------
# 2011
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.182
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     10.91
# Date:                Mon, 13 May 2019   Prob (F-statistic):           2.46e-34
# Time:                        22:49:47   Log-Likelihood:                -643.76
# No. Observations:                1103   AIC:                             1334.
# Df Residuals:                    1080   BIC:                             1449.
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
print('--------------------------------------------------')
print(2012)
new = year_filter_df.loc[year_filter_df['Year_of_Release_2012.0']==1]
se_df = sm.add_constant(new)

est = sm.OLS(se_df['Global_Sales'], 
               se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
         'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
         'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
         'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
          'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
         'Platform_WiiU', 'Platform_X360', 'Rating_E',
         'Rating_E10+','Rating_M', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
# --------------------------------------------------
# 2012
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     8.190
# Date:                Mon, 13 May 2019   Prob (F-statistic):           7.76e-24
# Time:                        22:49:47   Log-Likelihood:                -425.01
# No. Observations:                 638   AIC:                             898.0
# Df Residuals:                     614   BIC:                             1005.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
print('--------------------------------------------------')
print(2013)
new = year_filter_df.loc[year_filter_df['Year_of_Release_2013.0']==1]
se_df = sm.add_constant(new)

est = sm.OLS(se_df['Global_Sales'], 
               se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
         'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
         'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
         'Platform_3DS', 'Platform_DS', 'Platform_PC', 'Platform_PS3',
         'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
         'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
         'Rating_E10+','Rating_M', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
# --------------------------------------------------
# 2013
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.197
# Method:                 Least Squares   F-statistic:                     6.150
# Date:                Mon, 13 May 2019   Prob (F-statistic):           1.98e-17
# Time:                        22:49:47   Log-Likelihood:                -414.80
# No. Observations:                 525   AIC:                             881.6
# Df Residuals:                     499   BIC:                             992.4
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
print('--------------------------------------------------')
print(2014)
new = year_filter_df.loc[year_filter_df['Year_of_Release_2014.0']==1]
se_df = sm.add_constant(new)

est = sm.OLS(se_df['Global_Sales'], 
               se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
         'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
         'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
         'Platform_3DS', 'Platform_PC', 'Platform_PS3',
         'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
         'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
         'Rating_E10+','Rating_M', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
# --------------------------------------------------
# 2014
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     6.958
# Date:                Mon, 13 May 2019   Prob (F-statistic):           7.12e-20
# Time:                        22:49:48   Log-Likelihood:                -384.22
# No. Observations:                 559   AIC:                             818.4
# Df Residuals:                     534   BIC:                             926.6
# Df Model:                          24
# Covariance Type:            nonrobust
# ...

# %%
print('--------------------------------------------------')
print(2015)
new = year_filter_df.loc[year_filter_df['Year_of_Release_2015.0']==1]
se_df = sm.add_constant(new)

est = sm.OLS(se_df['Global_Sales'], 
               se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
         'Genre_Platform', 'Genre_Puzzle', 'Genre_Racing', 'Genre_Role-Playing',
         'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
         'Platform_3DS', 'Platform_PC', 'Platform_PS3',
         'Platform_PS4', 'Platform_PSP', 'Platform_PSV', 'Platform_Wii',
         'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
         'Rating_E10+','Rating_M', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
# --------------------------------------------------
# 2015
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     6.599
# Date:                Mon, 13 May 2019   Prob (F-statistic):           8.87e-19
# Time:                        22:49:48   Log-Likelihood:                -405.20
# No. Observations:                 591   AIC:                             860.4
# Df Residuals:                     566   BIC:                             970.0
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
original_df.loc[original_df['Year_of_Release']==2016].Platform.value_counts()
# Out:
# PS4     164
# XOne     87
# PSV      85
# PC       54
# 3DS      46
# PS3      38
# WiiU     14
# X360     13
# Wii       1
# Name: Platform, dtype: int64

# %%
print('--------------------------------------------------')
print(2016)
new = year_filter_df.loc[year_filter_df['Year_of_Release_2016.0']==1]
new = year_filter_df.loc[year_filter_df['Platform_Wii']!=1]
se_df = sm.add_constant(new)

est = sm.OLS(se_df['Global_Sales'], 
               se_df[['Genre_Action', 'Genre_Adventure', 'Genre_Fighting', 'Genre_Misc',
         'Genre_Platform', 'Genre_Racing', 'Genre_Role-Playing',
         'Genre_Shooter', 'Genre_Simulation', 'Genre_Sports', 'Genre_Strategy',
         'Platform_3DS', 'Platform_PC', 'Platform_PS3',
         'Platform_PS4','Platform_PSV',
         'Platform_WiiU', 'Platform_X360', 'Platform_XOne', 'Rating_E',
         'Rating_E10+','Rating_M', 'Rating_T']]
            ).fit()

print(est.summary())
# Out:
# --------------------------------------------------
# 2016
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                             OLS Regression Results
# ...
# Dep. Variable:           Global_Sales   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     109.9
# Date:                Mon, 13 May 2019   Prob (F-statistic):               0.00
# Time:                        22:49:48   Log-Likelihood:                -2519.1
# No. Observations:                3720   AIC:                             5084.
# Df Residuals:                    3697   BIC:                             5227.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
